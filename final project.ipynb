# %%
polac=0.66
liteac=0.46
tethac=0.72
xrpc=0.98
btc=0.47
eth=0.38
binan=0.41
card=0.99
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree   
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
from sklearn.preprocessing import LabelEncoder
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
print("Welcome to my cryptocurrency project,Have fun while testing it !")
print('the average of all models accuracy is ',((card+binan+eth+btc+xrpc+tethac+liteac+polac)/8))
wallet=int(input("Please enter your wallet value here to start trading and see recommandations based on your specifications"))
print('In this program you will have to enter the coordinates of the day you will approximately try to withdraw your money')
years=int(input("Enter the date coordinates in this format pls yyyymmdd"))
def crypto(m,n):
    b=pd.read_csv(m)
    b['price']=b['price'].astype(np.int64)
    b['datecode']=b['datecode'].str.replace("-","")
    b['datecode']=b['datecode'].str.replace(" 00:00:00 UTC","")
    b['datecode']=b['datecode'].str.replace(" 23:29:55 UTC","")
    b['datecode']=b['datecode'].str.replace(" 23:39:21 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:18 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:21 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:28 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:28 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:28 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:11 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:23 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:17 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:15 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:20 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:19 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:03 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:14 UTC","")
    b['datecode']=b['datecode'].str.replace(" 00:05:12 UTC","")
    b['datecode']=b['datecode'].astype(int)
    b['price']=b['price'].astype(np.int64)
    x=b[['datecode',"total_volume"]]
    y=b['price']
    plt.plot(b['datecode'], b['price'])
    n=n+" price over time"
    plt.title(n)
    plt.xlabel('year')
    plt.ylabel('price')
    plt.show() 
    modela=LinearRegression()
    modela.fit(x, y)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10) 
    print("Accuracy={:.2f}".format(modela.score(x_test, y_test)))
    from sklearn.metrics.pairwise import euclidean_distances
    euclidean_distances(x,x)
    n_neighbors=30
    scores=[]
    for k in range(1,30):
        knn=KNeighborsClassifier(n_neighbors-k)
        knn.fit(x_train,y_train)
        y_pred=knn.predict(x_test)
        scores.append(round(accuracy_score(y_pred,y_test),2))
    trees=tree.DecisionTreeClassifier()
    trees.fit(x_train,y_train)
    y_pred=trees.predict(x_test)
    print("new_score:{}".format(accuracy_score(y_test,y_pred)))
    col=RandomForestClassifier(n_estimators=100)
    col.fit(x_train,y_train)    
    plt.plot(range(1,30),scores)
    plt.xlabel('Value K for KNN')
    plt.ylabel('Testing Accuracy')
    b=modela.predict(x)
    print(b)
# Out:
# Welcome to my cryptocurrency project,Have fun while testing it !
# the average of all models accuracy is  0.63375
# In this program you will have to enter the coordinates of the day you will approximately try to withdraw your money

# %%
def polka():
    crypto("polkadot.csv","Polkadot")
polka()
print('the Original accuracy is far better')
# Out:
# Accuracy=0.66
# new_score:0.30666666666666664
# [ 3.29614426  3.29776272  3.18563063  3.19320246  4.65614697  4.17985299
#   4.38827365  5.54498423  5.97448617  6.46722403  5.04980791  4.43719829
#   4.2990856   4.63191769  4.77944275  4.82657685  5.3295529   5.48976684
#   5.21000568  4.92216648  4.41959143  3.96905538  4.10715996  4.03857439
#   3.89520535  4.26035918  4.59422639  4.44087142  4.21008468  4.11043941
#   4.20699308  3.92966536  3.79972905  4.13535594  4.47826345  3.89626534
#   3.90120332  3.91628087  3.79485067  3.61480683  3.61588976  3.85541764
#   3.88392194  3.7605739   3.9497532   4.01991824  3.67226524  3.62247405
#   3.77029373  4.04367088  4.06387381  4.06104948  3.95084348  3.88703351
#   3.75482172  3.97673518  3.86479744  3.91170254  3.82604593  3.88930473
#   3.57322015  3.6281423   3.66499055  3.85012739  3.94214034  3.84714767
#   3.91286215  3.76063826  3.72063298  4.29539812  4.26874842  4.04983054
# ...

# %%
def lite():
    crypto("litecoin.csv","Litecoin")
lite()
print('the new accuracy is better')
# Out:
# Accuracy=0.48
# new_score:0.4466338259441708
# [-4.71460726 -4.71361696 -4.71262667 ... 99.46946691 97.96587811
#  95.16755098]
# the new accuracy is better

# %%
def tether():
    crypto("tether.csv","Tether")
tether()
# Out:
# Accuracy=0.06
# new_score:0.6878980891719745
# [0.86859577 0.86794641 0.86791268 ... 0.51612491 0.52380435 0.51699062]

# %%
def xrp():
    crypto("XRP.csv","XRP")
xrp()
# Out:
# Accuracy=0.15
# new_score:0.9863945578231292
# [0.0344136  0.03441257 0.03441154 ... 0.25398198 0.23943401 0.16129933]

# %%
def btc():
    crypto("bitcoin.csv","bitcoin")
btc()
# Out:
# Accuracy=0.60
# new_score:0.009852216748768473
# [-1899.76213147 -1899.64736218 -1899.53259289 ... 22043.19245339
#  23106.66804182 21105.00724385]

# %%
def eth():
    crypto("ethereum.csv","ethereum")
eth()
# Out:
# Accuracy=0.56
# new_score:0.2171945701357466
# [  -9.9595949    -9.94675732   -9.90340827 ... 1083.73847285 1131.05331785
#  1027.42881899]

# %%
def bnc():
    crypto("binance.csv","binance")
bnc()
# Out:
# Accuracy=0.67
# new_score:0.4409722222222222
# [-32.61767494 -32.61482994 -32.61198599 ... 249.89059092 207.10796064
#  226.69728164]

# %%
def ada():
    crypto("cardano.csv","cardano")
ada()
# Out:
# Accuracy=0.52
# new_score:0.9964539007092199
# [-0.1059586  -0.10589719 -0.10517181 ...  1.15848418  1.09560609
#   0.80237515]
